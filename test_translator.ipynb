# %% [markdown]
# # PLEASE RUN THIS COLAB ON GPU DEVICE

# %% [markdown]
# # data import and repositories loading

# %%
# !gdown 1nKFype1xAnQDzZWkf3yVhsrABNQANmQa # train data to get the vocabulary
# !gdown 1EoWbUOAgHwE7vX0UOXlbPj6QwGrz8ApV # test data
# !gdown 14Er6664Ny_IlNUH4L3jCZUf-Vg72bL-6 # encoder load
# !gdown 1ASvNKDdTcUP_hnWjAwKh26ebXcSvIDWf # decoder load

# %%
# !git clone https://github.com/44Ap0pt0se54/MachineTranslator.git
from MachineTranslator import Translator

# %% [markdown]
# # Performances of loaded model on test data

# %%
MyModel = Translator.Translator()
MyModel.load() # GPU is needed

# %%
MyModel.test_model()

# %%
MyModel.test_random(n=5)

# %%
MyModel.translate_sentence("i am surprised the training vocabulary lets me say that this machine translator sucks")
